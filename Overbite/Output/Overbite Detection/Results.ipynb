# %% [markdown]
# Left left og right right:

# %% [markdown]
# Model: os.path.join("..", "Output", "Modeller", "Final Model", "Final_model_0014999.pth")
#
#  Mean Radial Error: 0.22 mm
# \Successful Detection Rate:
#   • ≤ 0.5 mm: 89.33%
#   • ≤ 1.0 mm: 96.00%
#   • ≤ 2.0 mm: 99.00%
# Patient-level summary saved to: ..\Output\Overbite Detection\Overbite_Classification1.csv
#
# Toothset Classification Accuracy: 97.22% (70 out of 72)
# Weighted Cohen’s Kappa: 0.9927
# Total patients evaluated: 72
# Patients excluded (NONE): 3
#
# Mean Radial Error: 0.22 mm
# \Successful Detection Rate:
#   • ≤ 0.5 mm: 89.33%
#   • ≤ 1.0 mm: 96.00%
#   • ≤ 2.0 mm: 99.00%
# Patient-level summary saved to: ..\Output\Overbite Detection\Overbite_Classification2.csv
#
# Toothset Classification Accuracy: 94.44% (68 out of 72)
# Weighted Cohen’s Kappa: 0.9841
# Total patients evaluated: 72
# Patients excluded (NONE): 3
#
# Mean Radial Error: 0.22 mm
# \Successful Detection Rate:
#   • ≤ 0.5 mm: 89.33%
#   • ≤ 1.0 mm: 96.00%
#   • ≤ 2.0 mm: 99.00%
# Patient-level summary saved to: ..\Output\Overbite Detection\Overbite_Classification3.csv
#
# Toothset Classification Accuracy: 95.89% (70 out of 73)
# Weighted Cohen’s Kappa: 0.9906
# Total patients evaluated: 73
# Patients excluded (NONE): 2
#
# Mean Radial Error: 0.22 mm
# \Successful Detection Rate:
#   • ≤ 0.5 mm: 89.33%
#   • ≤ 1.0 mm: 96.00%
#   • ≤ 2.0 mm: 99.00%
# Patient-level summary saved to: ..\Output\Overbite Detection\Overbite_Classification4.csv
#
# Toothset Classification Accuracy: 95.83% (69 out of 72)
# Weighted Cohen’s Kappa: 0.9906
# Total patients evaluated: 72
# Patients excluded (NONE): 3
#
#  Mean Radial Error: 0.22 mm
# \Successful Detection Rate:
#   • ≤ 0.5 mm: 89.33%
#   • ≤ 1.0 mm: 96.00%
#   • ≤ 2.0 mm: 99.00%
# Patient-level summary saved to: ..\Output\Overbite Detection\Overbite_Classification5.csv
#
# Toothset Classification Accuracy: 94.59% (70 out of 74)
# Weighted Cohen’s Kappa: 0.9860
# Total patients evaluated: 74
# Patients excluded (NONE): 1
#
#  Mean Radial Error: 0.22 mm
# \Successful Detection Rate:
#   • ≤ 0.5 mm: 89.33%
#   • ≤ 1.0 mm: 96.00%
#   • ≤ 2.0 mm: 99.00%
# Patient-level summary saved to: ..\Output\Overbite Detection\Overbite_Classification6.csv
#
# Toothset Classification Accuracy: 94.59% (70 out of 74)
# Weighted Cohen’s Kappa: 0.9875
# Total patients evaluated: 74
# Patients excluded (NONE): 1
#
#  Mean Radial Error: 0.22 mm
# \Successful Detection Rate:
#   • ≤ 0.5 mm: 89.33%
#   • ≤ 1.0 mm: 96.00%
#   • ≤ 2.0 mm: 99.00%
# Patient-level summary saved to: ..\Output\Overbite Detection\Overbite_Classification7.csv
#
# Toothset Classification Accuracy: 95.89% (70 out of 73)
# Weighted Cohen’s Kappa: 0.9894
# Total patients evaluated: 73
# Patients excluded (NONE): 2
#
#  Mean Radial Error: 0.22 mm
# \Successful Detection Rate:
#   • ≤ 0.5 mm: 89.33%
#   • ≤ 1.0 mm: 96.00%
#   • ≤ 2.0 mm: 99.00%
# Patient-level summary saved to: ..\Output\Overbite Detection\Overbite_Classification8.csv
#
# Toothset Classification Accuracy: 94.52% (69 out of 73)
# Weighted Cohen’s Kappa: 0.9882
# Total patients evaluated: 73
# Patients excluded (NONE): 2
#
#  Mean Radial Error: 0.22 mm
# \Successful Detection Rate:
#   • ≤ 0.5 mm: 89.33%
#   • ≤ 1.0 mm: 96.00%
#   • ≤ 2.0 mm: 99.00%
# Patient-level summary saved to: ..\Output\Overbite Detection\Overbite_Classification9.csv
#
# Toothset Classification Accuracy: 97.30% (72 out of 74)
# Weighted Cohen’s Kappa: 0.9935
# Total patients evaluated: 74
# Patients excluded (NONE): 1
#
# Mean Radial Error: 0.22 mm
# \Successful Detection Rate:
#   • ≤ 0.5 mm: 89.33%
#   • ≤ 1.0 mm: 96.00%
#   • ≤ 2.0 mm: 99.00%
# Patient-level summary saved to: ..\Output\Overbite Detection\Overbite_Classification10.csv
#
# Toothset Classification Accuracy: 93.15% (68 out of 73)
# Weighted Cohen’s Kappa: 0.9836
# Total patients evaluated: 73
# Patients excluded (NONE): 2
